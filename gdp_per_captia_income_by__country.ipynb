# %% [markdown]
# <a href="https://colab.research.google.com/github/mabhatti76/mabhatti76/blob/main/gdp_per_captia_income_by__country.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %%
df = pd.read_csv("/content/drive/MyDrive/JUSTIT/Pandas/Resources/GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Use this section to explore and inspect dataset.

# %%
df.head()
# some of columns have 0
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.tail()
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021

# %%
df.shape
# 223 countries and terrotories
# Out:
# (223, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223 entries, 1 to 223
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country/Territory   223 non-null    object
#  1   UN_Region           223 non-null    object
#  2   IMF_Estimate        223 non-null    int64
#  3   IMF_Year            223 non-null    int64
#  4   WorldBank_Estimate  223 non-null    int64
#  5   WorldBank_Year      223 non-null    int64
#  6   UN_Estimate         223 non-null    int64
#  7   UN_Year             223 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# UN_Year not returned
# Out:
#         IMF_Estimate     IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# count     223.000000   223.000000          223.000000      223.000000
# mean    15351.632287  1787.098655        18927.417040     1957.278027
# std     22550.899445   650.695912        29103.564915      353.145867
# min         0.000000     0.000000            0.000000        0.000000
# 25%      1406.500000  2023.000000         2273.500000     2021.000000
# 50%      5421.000000  2023.000000         6805.000000     2021.000000
# 75%     19697.000000  2023.000000        23715.000000     2021.000000
# max    132372.000000  2023.000000       234316.000000     2021.000000
#
#          UN_Estimate
# count     223.000000
# mean    17767.304933
# std     28698.104167
# min         0.000000
# 25%      2039.000000
# 50%      6396.000000
# 75%     20740.000000
# max    234317.000000

# %%
df.UN_Year.value_counts()
# Out:
# UN_Year
# 2021          213
# 0               9
# [n 10]2021      1
# Name: count, dtype: int64

# %%
# remove [n 10] and change datatype of this column to int

# %%
df.sample(10)
# Out:
#               Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 114                     Armenia      Asia          8007      2023
# 205                Burkina Faso    Africa           900      2023
# 129                        Iraq      Asia          6180      2023
# 58    Sint Maarten (Dutch part)  Americas             0         0
# 1                        Monaco    Europe             0         0
# 159            Papua New Guinea   Oceania          3517      2023
# 136                   Guatemala  Americas          5358      2023
# 31       British Virgin Islands  Americas             0         0
# 65   Saint Martin (French part)  Americas             0         0
# 146                       Samoa   Oceania          4436      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 114                4967            2021         4967    2021
# 205                 893            2021          893    2021
# 129                4775            2021         4686    2021
# 58                28988            2018        26199    2021
# 1                234316            2021       234317    2021
# 159                2673            2021         2673    2021
# 136                5026            2021         4883    2021
# 31                    0               0        49444    2021
# 65                21921            2014            0       0
# 146                3857            2021         3919    2021

# %%
df.UN_Region.value_counts()
# number of countries per region
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
df[df.UN_Region=="World"]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 93             World     World         13440      2023               12235
#
#     WorldBank_Year  UN_Estimate UN_Year
# 93            2021        12230    2021

# %%
df.dtypes
# Out:
# Country/Territory     object
# UN_Region             object
# IMF_Estimate           int64
# IMF_Year               int64
# WorldBank_Estimate     int64
# WorldBank_Year         int64
# UN_Estimate            int64
# UN_Year               object
# dtype: object

# %%
df[df.UN_Region=="Europe"]
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                    Monaco    Europe             0         0
# 2             Liechtenstein    Europe             0         0
# 3                Luxembourg    Europe        132372      2023
# 4                   Ireland    Europe        114581      2023
# 6                    Norway    Europe        101103      2023
# 7               Switzerland    Europe         98767      2023
# 9               Isle of Man    Europe             0         0
# 13                  Iceland    Europe         75180      2023
# 14          Channel Islands    Europe             0         0
# 15            Faroe Islands    Europe             0         0
# 16                  Denmark    Europe         68827      2023
# 18              Netherlands    Europe         61098      2023
# 20                  Austria    Europe         56802      2023
# 22                   Sweden    Europe         55395      2023
# 23                  Finland    Europe         54351      2023
# 24                  Belgium    Europe         53377      2023
# 25               San Marino    Europe         52949      2023
# 28                  Germany    Europe         51383      2023
# 33           United Kingdom    Europe         46371      2023
# 34                   France    Europe         44408      2023
# 35                  Andorra    Europe         44387      2023
# 36      European Union[n 1]    Europe         39940      2023
# 40                    Malta    Europe         36989      2023
# 41                    Italy    Europe         36812      2023
# 51                 Slovenia    Europe         32214      2023
# 52           Czech Republic    Europe         31368      2023
# 53                    Spain    Europe         31223      2023
# 54                  Estonia    Europe         31209      2023
# 120                 Albania    Europe          7058      2023
# 127                 Moldova    Europe          6342      2023
# 133                  Kosovo    Europe          5641      2023
# 143                 Ukraine    Europe          4654      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1                234316            2021       234317    2021
# 2                157755            2020       169260    2021
# 9                 87158            2019            0       0
# 14                75153            2007            0       0
# 15                69010            2021            0       0
# 36                38411            2021        31875    2021
# 40                33487            2021        33642    2021
# 41                35658            2021        35579    2021
# 51                29291            2021        29135    2021
# 52                26821            2021        26809    2021
# 53                30104            2021        30058    2021
# 54                27944            2021        27991    2021
# 57                23723            2021        23844    2021
# 59                24568            2021        24651    2021
# 60                21148            2021        21267    2021
# 62                21392            2021        21390    2021
# 63                20193            2021        20571    2021
# 70                17685            2021        16983    2021
# 72                18000            2021        17736    2021
# 75                18728            2021        18728    2021
# 78                14858            2021        14698    2021
# 87                12222            2021        12207    2021
# 90                12195            2021        12259    2021
# 103                9466            2021         9252    2021
# 106                9230            2021         8643    2021
# 112                7143            2021         7143    2021
# 115                7302            2021         7121    2021
# 118                6695            2021         6600    2021
# 120                6493            2021         6396    2021
# 127                5231            2021         4468    2021
# 133                5270            2021         5663    2021
# 143                4836            2021         4596    2021

# %%
df.IMF_Estimate.mean()
# Out:
# 15351.632286995517

# %%
df.WorldBank_Estimate.mean()
# Out:
# 18927.417040358745

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
# Countries in Europe below avarege

# %%
df[(df["UN_Region"]=="Europe") & (df["IMF_Estimate"]<df.IMF_Estimate.mean()) & (df["IMF_Estimate"]!=0)]
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 87                 Bulgaria    Europe         14893      2023
# 90                   Russia    Europe         14403      2023
# 103              Montenegro    Europe         11289      2023
# 106                  Serbia    Europe         10849      2023
# 112  Bosnia and Herzegovina    Europe          8223      2023
# 115                 Belarus    Europe          7944      2023
# 118         North Macedonia    Europe          7384      2023
# 120                 Albania    Europe          7058      2023
# 127                 Moldova    Europe          6342      2023
# 133                  Kosovo    Europe          5641      2023
# 143                 Ukraine    Europe          4654      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 87                12222            2021        12207    2021
# 90                12195            2021        12259    2021
# 103                9466            2021         9252    2021
# 106                9230            2021         8643    2021
# 112                7143            2021         7143    2021
# 115                7302            2021         7121    2021
# 118                6695            2021         6600    2021
# 120                6493            2021         6396    2021
# 127                5231            2021         4468    2021
# 133                5270            2021         5663    2021
# 143                4836            2021         4596    2021

# %%
df[(df["UN_Region"]=="Europe") & (df["WorldBank_Estimate"]<df.WorldBank_Estimate.mean()) & (df["WorldBank_Estimate"]!=0)]
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 70                  Croatia    Europe         20537      2023
# 72                   Poland    Europe         19912      2023
# 75                  Hungary    Europe         19385      2023
# 78                  Romania    Europe         18530      2023
# 87                 Bulgaria    Europe         14893      2023
# 90                   Russia    Europe         14403      2023
# 103              Montenegro    Europe         11289      2023
# 106                  Serbia    Europe         10849      2023
# 112  Bosnia and Herzegovina    Europe          8223      2023
# 115                 Belarus    Europe          7944      2023
# 118         North Macedonia    Europe          7384      2023
# 120                 Albania    Europe          7058      2023
# 127                 Moldova    Europe          6342      2023
# 133                  Kosovo    Europe          5641      2023
# 143                 Ukraine    Europe          4654      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 70                17685            2021        16983    2021
# 72                18000            2021        17736    2021
# 75                18728            2021        18728    2021
# 78                14858            2021        14698    2021
# 87                12222            2021        12207    2021
# 90                12195            2021        12259    2021
# 103                9466            2021         9252    2021
# 106                9230            2021         8643    2021
# 112                7143            2021         7143    2021
# 115                7302            2021         7121    2021
# 118                6695            2021         6600    2021
# 120                6493            2021         6396    2021
# 127                5231            2021         4468    2021
# 133                5270            2021         5663    2021
# 143                4836            2021         4596    2021

# %%
df[(df["UN_Region"]=="Europe") & (df["UN_Estimate"]<df.UN_Estimate.mean()) & (df["UN_Estimate"]!=0)]
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 70                  Croatia    Europe         20537      2023
# 72                   Poland    Europe         19912      2023
# 78                  Romania    Europe         18530      2023
# 87                 Bulgaria    Europe         14893      2023
# 90                   Russia    Europe         14403      2023
# 103              Montenegro    Europe         11289      2023
# 106                  Serbia    Europe         10849      2023
# 112  Bosnia and Herzegovina    Europe          8223      2023
# 115                 Belarus    Europe          7944      2023
# 118         North Macedonia    Europe          7384      2023
# 120                 Albania    Europe          7058      2023
# 127                 Moldova    Europe          6342      2023
# 133                  Kosovo    Europe          5641      2023
# 143                 Ukraine    Europe          4654      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 70                17685            2021        16983    2021
# 72                18000            2021        17736    2021
# 78                14858            2021        14698    2021
# 87                12222            2021        12207    2021
# 90                12195            2021        12259    2021
# 103                9466            2021         9252    2021
# 106                9230            2021         8643    2021
# 112                7143            2021         7143    2021
# 115                7302            2021         7121    2021
# 118                6695            2021         6600    2021
# 120                6493            2021         6396    2021
# 127                5231            2021         4468    2021
# 133                5270            2021         5663    2021
# 143                4836            2021         4596    2021

# %%
df[df["Country/Territory"]=="United Kingdom"]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 33    United Kingdom    Europe         46371      2023               46510
#
#     WorldBank_Year  UN_Estimate UN_Year
# 33            2021        46542    2021

# %%
df[["IMF_Estimate", "WorldBank_Estimate", "UN_Estimate"]].mean()
# Out:
# IMF_Estimate          15351.632287
# WorldBank_Estimate    18927.417040
# UN_Estimate           17767.304933
# dtype: float64

# %%
## Which countries in Europe has higher GDP than UK?

# %%
df[(df["UN_Region"]=="Europe") & (df["IMF_Estimate"]>=46371)].reset_index()
# Out:
#     index Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0       3        Luxembourg    Europe        132372      2023
# 1       4           Ireland    Europe        114581      2023
# 2       6            Norway    Europe        101103      2023
# 3       7       Switzerland    Europe         98767      2023
# 4      13           Iceland    Europe         75180      2023
# 5      16           Denmark    Europe         68827      2023
# 6      18       Netherlands    Europe         61098      2023
# 7      20           Austria    Europe         56802      2023
# 8      22            Sweden    Europe         55395      2023
# 9      23           Finland    Europe         54351      2023
# 10     24           Belgium    Europe         53377      2023
# 11     25        San Marino    Europe         52949      2023
# 12     28           Germany    Europe         51383      2023
# 13     33    United Kingdom    Europe         46371      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0               133590            2021       133745    2021
# 1               100172            2021       101109    2021
# 2                89154            2021        89242    2021
# 3                91992            2021        93525    2021
# 4                68728            2021        69133    2021
# 5                68008            2021        68037    2021
# 6                57768            2021        57871    2021
# 7                53638            2021        53840    2021
# 8                61029            2021        60730    2021
# 9                53655            2021        53703    2021
# 10               51247            2021        51166    2021
# 11               45320            2020        50425    2021
# 12               51204            2021        51073    2021
# 13               46510            2021        46542    2021

# %%
df[df["Country/Territory"]=="Turkey"]
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 99            Turkey      Asia         11931      2023                9661
#
#     WorldBank_Year  UN_Estimate UN_Year
# 99            2021         9661    2021

# %%
df[(df["UN_Region"]=="Asia") & (df["IMF_Estimate"]>=11931)]
# Out:
#        Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 8              Singapore      Asia         91100      2023
# 11                 Qatar      Asia         83891      2023
# 21                Israel      Asia         55535      2023
# 27             Hong Kong      Asia         52429      2023
# 29                 Macau      Asia         50571      2023
# 30  United Arab Emirates      Asia         49451      2023
# 44                 Japan      Asia         35385      2023
# 45                Brunei      Asia         35103      2023
# 46                Taiwan      Asia         33907      2023
# 47                Cyprus      Asia         33807      2023
# 48                Kuwait      Asia         33646      2023
# 49           South Korea      Asia         33393      2023
# 55          Saudi Arabia      Asia         29922      2023
# 56               Bahrain      Asia         28385      2023
# 64                  Oman      Asia         21960      2023
# 83              Maldives      Asia         17626      2023
# 91                 China      Asia         13721      2023
# 94              Malaysia      Asia         13382      2023
# 95          Turkmenistan      Asia         13065      2023
# 97            Kazakhstan      Asia         12306      2023
# 99                Turkey      Asia         11931      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 8                72794            2021        66822    2021
# 11               66838            2021        66799    2021
# 21               52171            2021        54111    2021
# 27               49801            2021        49259    2021
# 29               43874            2021        43555    2021
# 30               44316            2021        43295    2021
# 44               39313            2021        39650    2021
# 45               31449            2021        31449    2021
# 46                   0               0            0       0
# 47               31552            2021        32281    2021
# 48               24300            2020        32150    2021
# 49               34998            2021        34940    2021
# 55               23186            2021        23186    2021
# 56               26563            2021        26563    2021
# 64               19510            2021        19509    2021
# 83               10366            2021        10366    2021
# 91               12556            2021        12437    2021
# 94               11109            2021        11101    2021
# 95                7345            2019         8508    2021
# 97               10374            2021        10055    2021
# 99                9661            2021         9661    2021

# %% [markdown]
# ## groupby()

# %% [markdown]
# [Learn more about groupby](https://www.geeksforgeeks.org/pandas-groupby/)

# %%
df.groupby("UN_Region")["IMF_Estimate"].mean().sort_values()
# Out:
# UN_Region
# Africa       2802.345455
# Oceania      9133.150000
# Americas    11871.041667
# World       13440.000000
# Asia        16665.254902
# Europe      34446.750000
# Name: IMF_Estimate, dtype: float64

# %%
df.groupby("UN_Region")["WorldBank_Estimate"].mean().sort_values()
# Out:
# UN_Region
# Africa       2470.836364
# World       12235.000000
# Asia        13921.313725
# Oceania     15113.650000
# Americas    18565.125000
# Europe      45193.687500
# Name: WorldBank_Estimate, dtype: float64

# %%
df.groupby("UN_Region")["UN_Estimate"].mean().sort_values()
# Out:
# UN_Region
# Africa       2417.927273
# World       12230.000000
# Oceania     12613.750000
# Asia        14069.019608
# Americas    18703.750000
# Europe      40610.791667
# Name: UN_Estimate, dtype: float64

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.nlargest(5, columns="IMF_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 6            Norway    Europe        101103      2023               89154
# 7       Switzerland    Europe         98767      2023               91992
# 8         Singapore      Asia         91100      2023               72794
#
#    WorldBank_Year  UN_Estimate UN_Year
# 3            2021       133745    2021
# 4            2021       101109    2021
# 6            2021        89242    2021
# 7            2021        93525    2021
# 8            2021        66822    2021

# %%
df.nlargest(5, columns="WorldBank_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 5           Bermuda  Americas             0         0              114090
# 4           Ireland    Europe        114581      2023              100172
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 5            2021       112653    2021
# 4            2021       101109    2021

# %%
df.nlargest(5, columns="UN_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 5           Bermuda  Americas             0         0              114090
# 4           Ireland    Europe        114581      2023              100172
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 5            2021       112653    2021
# 4            2021       101109    2021

# %%
df.nsmallest(5, columns="UN_Estimate")
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 9         Isle of Man    Europe             0         0               87158
# 14    Channel Islands    Europe             0         0               75153
# 15      Faroe Islands    Europe             0         0               69010
# 37  US Virgin Islands  Americas             0         0               39552
# 42               Guam   Oceania             0         0               35905
#
#     WorldBank_Year  UN_Estimate UN_Year
# 9             2019            0       0
# 14            2007            0       0
# 15            2021            0       0
# 37            2020            0       0
# 42            2021            0       0

# %%
df.IMF_Year.value_counts()
# Out:
# IMF_Year
# 2023    193
# 0        26
# 2020      2
# 2022      2
# Name: count, dtype: int64

# %%
df.WorldBank_Year.value_counts()
# Out:
# WorldBank_Year
# 2021    199
# 2020      7
# 0         7
# 2019      3
# 2018      2
# 2014      2
# 2007      1
# 2011      1
# 2015      1
# Name: count, dtype: int64

# %%
df.UN_Year.value_counts()
# Out:
# UN_Year
# 2021          213
# 0               9
# [n 10]2021      1
# Name: count, dtype: int64

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %%
df[(df["IMF_Estimate"]<df["IMF_Estimate"].mean()) & (df["IMF_Estimate"] != 0)]
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 87           Bulgaria    Europe         14893      2023               12222
# 88              Palau   Oceania         14804      2023               12084
# 89         Costa Rica  Americas         14733      2023               12472
# 90             Russia    Europe         14403      2023               12195
# 91              China      Asia         13721      2023               12556
# ..                ...       ...           ...       ...                 ...
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 87             2021        12207    2021
# 88             2021        12084    2021
# 89             2021        12472    2021
# 90             2021        12259    2021
# 91             2021        12437    2021
# ..              ...          ...     ...
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021
#
# [133 rows x 8 columns]

# %%
df.shape
# Out:
# (223, 8)

# %%
df["IMF_Estimate"].mean()
# Out:
# 15351.632286995517

# %% [markdown]
# ### IMF estimate 0 values

# %%
df[df["IMF_Estimate"]==0]
# Out:
#               Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                        Monaco    Europe             0         0
# 2                 Liechtenstein    Europe             0         0
# 5                       Bermuda  Americas             0         0
# 9                   Isle of Man    Europe             0         0
# 10               Cayman Islands  Americas             0         0
# 14              Channel Islands    Europe             0         0
# 15                Faroe Islands    Europe             0         0
# 19                    Greenland  Americas             0         0
# 31       British Virgin Islands  Americas             0         0
# 37            US Virgin Islands  Americas             0         0
# 39                New Caledonia   Oceania             0         0
# 42                         Guam   Oceania             0         0
# 58    Sint Maarten (Dutch part)  Americas             0         0
# 61     Northern Mariana Islands   Oceania             0         0
# 65   Saint Martin (French part)  Americas             0         0
# 68     Turks and Caicos Islands  Americas             0         0
# 71             French Polynesia   Oceania             0         0
# 76                 Cook Islands   Oceania             0         0
# 77                     Anguilla  Americas             0         0
# 82                     Cura̤ao  Americas             0         0
# 85                   Montserrat  Americas             0         0
# 86               American Samoa   Oceania             0         0
# 104                        Cuba  Americas             0         0
# 196                    Zanzibar    Africa             0         0
# 204                       Syria      Asia             0         0
# 212                 North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 1                234316            2021       234317    2021
# 2                157755            2020       169260    2021
# 5                114090            2021       112653    2021
# 9                 87158            2019            0       0
# 10                86569            2021        85250    2021
# 14                75153            2007            0       0
# 15                69010            2021            0       0
# 19                54571            2020        58185    2021
# 31                    0               0        49444    2021
# 37                39552            2020            0       0
# 39                37160            2021        34994    2021
# 42                35905            2021            0       0
# 58                28988            2018        26199    2021
# 61                23707            2019            0       0
# 65                21921            2014            0       0
# 68                20909            2021        20909    2021
# 71                19915            2021        19915    2021
# 76                    0               0        19264    2021
# 77                    0               0        19216    2021
# 82                17718            2021        14183    2021
# 85                    0               0        16199    2021
# 86                15743            2021            0       0
# 104                9500            2020        11255    2021
# 196                   0               0         1211    2021
# 204                 533            2020          925    2021
# 212                   0               0          654    2021

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %% [markdown]
# ## Which country has highest UN Estimate?

# %%
df.nlargest(1, "UN_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %%
df.head(1)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %%
d = df[df['UN_Estimate']==df['UN_Estimate'].max()]
d[['Country/Territory','UN_Estimate']]
# Out:
#   Country/Territory  UN_Estimate
# 1            Monaco       234317

# %%
df.loc[df['UN_Estimate'].idxmax()]
# Out:
# Country/Territory     Monaco
# UN_Region             Europe
# IMF_Estimate               0
# IMF_Year                   0
# WorldBank_Estimate    234316
# WorldBank_Year          2021
# UN_Estimate           234317
# UN_Year                 2021
# Name: 1, dtype: object

# %%
df.sort_values(by=["UN_Estimate"], ascending=False, ignore_index=True).head(1)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 0            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 0            2021       234317    2021

# %% [markdown]
# ## Which country has highest Worlbank Estimate?

# %%
df.nlargest(1, "WorldBank_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021

# %%
df.loc[df['WorldBank_Estimate'].idxmax()]
# Out:
# Country/Territory     Monaco
# UN_Region             Europe
# IMF_Estimate               0
# IMF_Year                   0
# WorldBank_Estimate    234316
# WorldBank_Year          2021
# UN_Estimate           234317
# UN_Year                 2021
# Name: 1, dtype: object

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %%
df.nlargest(1, "IMF_Estimate")
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 3        Luxembourg    Europe        132372      2023              133590
#
#    WorldBank_Year  UN_Estimate UN_Year
# 3            2021       133745    2021

# %%
df.sort_values(by=["IMF_Estimate"], ascending=False, ignore_index=True).head(1)
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 0        Luxembourg    Europe        132372      2023              133590
#
#    WorldBank_Year  UN_Estimate UN_Year
# 0            2021       133745    2021

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %% [markdown]
# ## Filling 0 Values by average

# %%
import numpy as np

# %%
df["IMF_Estimate"] = df["IMF_Estimate"].replace(0, np.nan)
# replace 0 with null values

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe           NaN         0              234316
# 2     Liechtenstein    Europe           NaN         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas           NaN         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
# Calculate the average of 'worldbank' and 'un' columns
df['avg_worldbank_un'] = df[['WorldBank_Estimate', 'UN_Estimate']].mean(axis=1)
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe           NaN         0              234316
# 2     Liechtenstein    Europe           NaN         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas           NaN         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year  avg_worldbank_un
# 1            2021       234317    2021          234316.5
# 2            2020       169260    2021          163507.5
# 3            2021       133745    2021          133667.5
# 4            2021       101109    2021          100640.5
# 5            2021       112653    2021          113371.5

# %%
# Fill the null values in 'imf' column with the calculated average
df["IMF_Estimate"] = df["IMF_Estimate"].fillna(df["avg_worldbank_un"])

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year  avg_worldbank_un
# 1            2021       234317    2021          234316.5
# 2            2020       169260    2021          163507.5
# 3            2021       133745    2021          133667.5
# 4            2021       101109    2021          100640.5
# 5            2021       112653    2021          113371.5

# %%
# Drop the temporary 'avg_worldbank_un' column if not needed
df.drop(columns=['avg_worldbank_un'], inplace=True)

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %% [markdown]
# [Visit this link to learn more about ffill](https://www.w3schools.com/python/pandas/ref_df_ffill.asp)

# %% [markdown]
# [Visit this link to learn more about bfill](https://www.w3schools.com/python/pandas/ref_df_bfill.asp)

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# df.dropna()
# remove null values from your data

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=50, figsize=(12,9))

plt.show()

# %%
df["WorldBank_Estimate"].agg(["min","max"])
# Out:
# min         0
# max    234316
# Name: WorldBank_Estimate, dtype: int64

# %%
234316/5
#1 bin size if bins=5
# Out:
# 46863.2

# %%
df[df["WorldBank_Estimate"]<=46863.2]["WorldBank_Estimate"].count()
# Out:
# 195

# %%
234316/10
#1 bin size if bins not given any number
# Out:
# 23431.6

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))

#23400/15 = 15300
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()
plt.figure(figsize = (10,8))
sns.heatmap(corr, annot = True, cmap = 'seismic') #GnBu for greenblue
# Out:
# <Axes: >

# %%
# creating correlation for the whole dataset for numeric values only
numeric_df = df.select_dtypes(include=[int, float])
corr = numeric_df.corr()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()
# Out:
#                     IMF_Estimate  UN_Estimate  WorldBank_Estimate
# IMF_Estimate            1.000000     0.976263            0.974294
# UN_Estimate             0.976263     1.000000            0.930331
# WorldBank_Estimate      0.974294     0.930331            1.000000

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(16,9))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, fmt=".2f", cmap = 'GnBu', annot_kws={"size": 12})

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %%
corr = df.select_dtypes(include=[int, float]).corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
#creating Barplot
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
fig = plt.figure(figsize=(8,5))

# Create a bar plot comparing IMF GDP estimates by region
sns.barplot(x="IMF_Estimate", y="UN_Region", data=df, ci=None, palette='colorblind')

# Show the plot
plt.show()
# Out:
# <ipython-input-149-842cc084a911>:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="IMF_Estimate", y="UN_Region", data=df, ci=None, palette='colorblind')
# <ipython-input-149-842cc084a911>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="IMF_Estimate", y="UN_Region", data=df, ci=None, palette='colorblind')

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, errorbar=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate",
                 data = df, errorbar = None)

ax.bar_label(ax.containers[0])


ax.set_title("Regions by IMF Estimate")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
#using the built in plot() method
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")

plt.show()

# %%
#using the sns barplot option
sns.barplot(x='IMF_Estimate', y='UN_Estimate', data=df, palette = 'magma', hue='UN_Region')

plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>50000].head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
df.shape
# Out:
# (223, 8)

# %% [markdown]
# ###Count Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create count plot excluding 'World' category
ax = sns.countplot(x="UN_Region", data=df[~(df.UN_Region=="World")], palette='magma') #removes the World category data=df[~(df.UN_Region=="World")

# Add count labels on top of bars
# ax.bar_label(ax.containers[0])
for labels in ax.containers:
    ax.bar_label(labels)

# Set plot title
plt.title("Number of Countries by Region")

# Show plot
plt.show()
# Out:
# <ipython-input-173-eb041ad09356>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="UN_Region", data=df[~(df.UN_Region=="World")], palette='magma') #removes the World category data=df[~(df.UN_Region=="World")

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe      101103.0      2023               89154
# 7        Switzerland    Europe       98767.0      2023               91992
# 8          Singapore      Asia       91100.0      2023               72794
# 9        Isle of Man    Europe       43579.0         0               87158
# 10    Cayman Islands  Americas       85909.5         0               86569
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021

# %%
data.shape
# Out:
# (218, 8)

# %%
data.UN_Estimate.mean()
# Out:
# 14729.47247706422

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q
# Out:
# 2039.0

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q
# Out:
# 20740.0

# %%
iqr = higher_q - lower_q
iqr
# Out:
# 18701.0

# %%
upper_boundary = higher_q + 1.5 * iqr
upper_boundary
# Out:
# 48791.5

# %%
lower_boundary = lower_q - 1.5 * iqr
lower_boundary
# Out:
# -26012.5

# %%
df_filtered = df[(df["UN_Estimate"] < upper_boundary) & (df["UN_Estimate"] > lower_boundary)]

# %%
df_filtered.head()
# Out:
#        Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 9            Isle of Man    Europe       43579.0         0
# 14       Channel Islands    Europe       37576.5         0
# 15         Faroe Islands    Europe       34505.0         0
# 29                 Macau      Asia       50571.0      2023
# 30  United Arab Emirates      Asia       49451.0      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 9                87158            2019            0       0
# 14               75153            2007            0       0
# 15               69010            2021            0       0
# 29               43874            2021        43555    2021
# 30               44316            2021        43295    2021

# %%
df_filtered.shape
# there were 223 rows - 196 = 27 outliers dropped
# Out:
# (196, 8)

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 9415.168367346938

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
#how can we create a table with following
df_filtered.WorldBank_Estimate.mean()
# Out:
# 11096.647959183674

# %%
df.WorldBank_Estimate.mean()
# Out:
# 18927.417040358745

# %%
df_filtered.IMF_Estimate.mean()
# Out:
# 11538.908163265307

# %%
df.IMF_Estimate.mean()
# Out:
# 19935.053811659192
